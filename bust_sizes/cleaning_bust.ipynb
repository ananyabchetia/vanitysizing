# %%
import pandas as pd
df=pd.read_csv('csv/bust.csv')
df
# Out:
#           Brands Letter_sizing   Bust
# 0         Amazon            XS  32.50
# 1         Amazon             S  34.50
# 2         Amazon             M  36.50
# 3         Amazon             L  39.25
# 4         Amazon            XL  42.25
# ..           ...           ...    ...
# 239  FashionNova            XS  32.50
# 240  FashionNova             S  34.50
# 241  FashionNova             M  36.50
# 242  FashionNova             L  39.25
# 243  FashionNova            XL  41.50
#
# [244 rows x 3 columns]

# %% [markdown]
# ## How many brands are here?

# %%
df['Brands'].nunique()
# Out:
# 43

# %%
df.isna().sum()
# Out:
# Brands           0
# Letter_sizing    0
# Bust             0
# dtype: int64

# %% [markdown]
# ## Remove string 'Size Charts' or 'size charts' from df['Brand']

# %%
df['Brands'] = df['Brands'].str.replace('size charts', '', case=False, regex=True).str.strip()
df
# Out:
#           Brands Letter_sizing   Bust
# 0         Amazon            XS  32.50
# 1         Amazon             S  34.50
# 2         Amazon             M  36.50
# 3         Amazon             L  39.25
# 4         Amazon            XL  42.25
# ..           ...           ...    ...
# 239  FashionNova            XS  32.50
# 240  FashionNova             S  34.50
# 241  FashionNova             M  36.50
# 242  FashionNova             L  39.25
# 243  FashionNova            XL  41.50
#
# [244 rows x 3 columns]

# %% [markdown]
# ## Make the first letter of the string from df['Brand'] capital.

# %%
df['Brands'] = df['Brands'].str.strip().str[0].str.upper() + df['Brands'].str.strip().str[1:]
df.head(40)
# Out:
#                        Brands Letter_sizing   Bust
# 0                      Amazon            XS  32.50
# 1                      Amazon             S  34.50
# 2                      Amazon             M  36.50
# 3                      Amazon             L  39.25
# 4                      Amazon            XL  42.25
# 5         Abercrombie & Fitch            XS  32.50
# 6         Abercrombie & Fitch             S  34.50
# 7         Abercrombie & Fitch             M  36.50
# 8         Abercrombie & Fitch             L  38.00
# 9                     Addidas           XXS  29.30
# 10                    Addidas            XS  31.30
# 11                    Addidas             S  33.70
# 12                    Addidas             M  36.00
# 13                    Addidas             L  38.60
# 14                    Addidas            XL  41.50
# 15                    Addidas           XXL  44.90
# 16                 Aerpostale           XXS  30.50
# 17                 Aerpostale            XS  31.50
# 18                 Aerpostale            XS  32.50
# 19                 Aerpostale             S  33.50
# 20                 Aerpostale             S  34.50
# 21                 Aerpostale             M  35.50
# 22                 Aerpostale             M  36.50
# 23                 Aerpostale             L  38.00
# 24                 Aerpostale             L  39.50
# 25                 Aerpostale            XL  41.00
# 26                 Aerpostale            XL  42.50
# 27                 Aerpostale           XXL  44.00
# 28                 Affliction            XS  32.50
# 29                      Alloy            XS  31.50
# 30                      Alloy           XXL  45.00
# 31                      Alloy          XXXL  49.00
# 32  American Eagle Outfitters           XXS  31.00
# 33  American Eagle Outfitters            XS  32.50
# 34                      Alloy            XS  25.00
# 35                      Alloy             S  27.00
# 36                      Alloy             S  28.00
# 37                      Alloy             M  29.00
# 38                      Alloy             M  30.00
# 39                      Alloy             L  31.00

# %% [markdown]
# ## only print where df['Brand'] and df['Letter_sizing'] is repeated.

# %%
df[df.duplicated(subset=['Brands', 'Letter_sizing'], keep=False)]
# Out:
#           Brands Letter_sizing   Bust
# 17    Aerpostale            XS  31.50
# 18    Aerpostale            XS  32.50
# 19    Aerpostale             S  33.50
# 20    Aerpostale             S  34.50
# 21    Aerpostale             M  35.50
# 22    Aerpostale             M  36.50
# 23    Aerpostale             L  38.00
# 24    Aerpostale             L  39.50
# 25    Aerpostale            XL  41.00
# 26    Aerpostale            XL  42.50
# 29         Alloy            XS  31.50
# 30         Alloy           XXL  45.00
# 34         Alloy            XS  25.00
# 35         Alloy             S  27.00
# 36         Alloy             S  28.00
# 37         Alloy             M  29.00
# 38         Alloy             M  30.00
# 39         Alloy             L  31.00
# 40         Alloy             L  32.00
# 41         Alloy            XL  40.00
# 42         Alloy            XL  40.00
# 43         Alloy           XXL  37.00
# 68          ASOS            XS  31.00
# 69          ASOS            XS  32.00
# 70          ASOS             S  33.00
# 71          ASOS             S  35.00
# 72          ASOS             M  37.00
# 73          ASOS             M  39.00
# 74          ASOS             L  41.00
# 75          ASOS             L  44.00
# 106  Francesca's             S  34.00
# 107  Francesca's             S  35.00
# 108  Francesca's             M  36.00
# 109  Francesca's             M  37.00
# 110  Francesca's             L  38.00
# 111  Francesca's             L  39.00
# 135        Hanes            XS  32.75
# 136        Hanes             S  34.75
# 137        Hanes             M  36.75
# 138        Hanes             L  39.75
# 139        Hanes            XL  42.75
# 140        Hanes            XS  31.50
# 141        Hanes             S  33.50
# 142        Hanes             M  35.50
# 143        Hanes             L  38.00
# 144        Hanes            XL  40.75
# 156    Hollister            XL  39.50
# 157    Hollister            XL  43.00

# %% [markdown]
# ## Find the brands that DO NOT have XS or XL.

# %%
df.to_csv('updated_busts.csv')

# %%
brands_with_xs = df.loc[df['Letter_sizing'] == 'XS', 'Brands'].unique()
brands_without_xs = df.loc[~df['Brands'].isin(brands_with_xs), 'Brands'].unique()
brands_without_xs
# Out:
# array(['Michael Kors'], dtype=object)

# %%
brands_with_xl = df.loc[df['Letter_sizing'] == 'XL', 'Brands'].unique()
brands_without_xl = df.loc[~df['Brands'].isin(brands_with_xl), 'Brands'].unique()
brands_without_xl
# Out:
# array(['Abercrombie & Fitch', 'Affliction', 'American Eagle Outfitters',
#        'Ann Taylor', 'ASOS', 'French Connection USA', 'Michael Kors'],
#       dtype=object)

# %% [markdown]
# ## Ok, let's find the average of these duplicates instead!
