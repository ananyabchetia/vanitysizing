# %% [markdown]
# ## My access token
#
# ### sk.eyJ1IjoiYWM1NzA4IiwiYSI6ImNtZml0eXR5ODBzeWgya29sZTFmbXAzY2sifQ.5vABqfPZdMGbBrlq4lJrLg

# %%
import requests 
url = 'http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=lil&limit=50&api_key=dd346e2d03010b8c30ada705306a7d50&format=json'
response = requests.get(url)
response
